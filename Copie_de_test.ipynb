# %% [markdown]
# <a href="https://colab.research.google.com/github/IAkharraz/Algebra/blob/main/Copie_de_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x='Bonjour!'

# %%
# @title
print(x)
# Out:
# Bonjour!

# %% [markdown]
# Bonjour $\sum_{i=1}^{n}x^2$
